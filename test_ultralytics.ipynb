# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt") # pass any model type

# %%
model.predict(source="data/handball_video.mp4", show = True)
# Out:
# Ultralytics YOLOv8.0.6 🚀 Python-3.10.1 torch-1.13.1 CPU
# Fusing layers...
# YOLOv8n summary: 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# video 1/1 (1/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 9 persons, 54.0ms
# video 1/1 (2/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 10 persons, 54.4ms
# video 1/1 (3/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 9 persons, 47.9ms
# video 1/1 (4/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 10 persons, 65.7ms
# video 1/1 (5/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 10 persons, 47.0ms
# video 1/1 (6/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 9 persons, 46.6ms
# video 1/1 (7/4677) /Users/bpugnaire/Dev/github/Handball_CV/data/handball_video.mp4: 384x640 9 persons, 48.4ms
# ...
